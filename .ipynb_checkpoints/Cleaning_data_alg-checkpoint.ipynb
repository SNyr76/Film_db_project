# %%
import sqlite3
import pandas as pd
import numpy as np
import re
#-*- coding: utf-8 -*-

# %%
##Query unclean data scraped from Wikipedia
conn = sqlite3.connect('films.sqlite')
cur = conn.cursor()
df=pd.read_sql_query('SELECT * FROM Film',conn)

conn.close()

# %%
df['name']=df['name'].apply(lambda x:x[1:].split('/')[1])
df['name']=df['name'].apply(lambda x:x.replace('_',' '))
import ast
df['data_a']=df['data'].apply(lambda x:ast.literal_eval(x))
decom=df['data_a'].apply(pd.Series)
decom=decom[['Directed by', 'Written by', 'Produced by', 'Starring',
       'Cinematography', 'Edited by', 'Music by', 'Release date',
       'Running time', 'Country','Language','Productioncompanies','Distributed by','Budget','Box office','Productioncompany']]
decom['Productioncompanies'] = decom['Productioncompanies'].fillna(decom.pop('Productioncompany'))

# %%
## wanted to get data that has budget boc office figures.  

decom=decom[(decom['Budget'].isna()==False)&(decom['Box office'].isna()==False)]
df=pd.merge(decom,df,left_index=True, right_index=True)

film_table=df
film_table=film_table[['name','id','Release date','Running time','Country','Language','Budget','Box office']]

# %%
from datetime import datetime
from dateutil import parser

def clean_date(str_):
    str_=str(str_)
    if re.search(r'(\d{4}-\d{2}-\d{2})', str_) != None:
        date=re.search(r'(\d{4}-\d{2}-\d{2})', str_).group(1)
        try:
            date=parser.parse(date)
            date=date.strftime("%Y-%m-%d")
        except:
            pass
        return date 
    elif re.search(r'(\d{4}-\d{2})', str_) != None:
        date=re.search(r'(\d{4}-\d{2})', str_).group(1)
        try:
            date=parser.parse(date)
            date=date.strftime("%Y-%m-%d")
        except:
            date='N/A'
        return date
   
    elif str_== 'N/A':
        return str_
    else:
        try:
            date=parser.parse(date)
            date=date.strftime("%Y-%m-%d")
        except:
            date='N/A'
        return date

# %%
def time_clean(time):
    try:
        time=str(time)
        time=time.lower()
    except:
        pass
    try:
        time=time.split()
    except:
        pass
    minute_vari=['minutes','mins','min','mins.']
    hour_vari=['h','hour','hours','hours.']
    if len(time)>1:
    
        if (len(time)==2) and (time[1] in minute_vari):
            return time[0]
        elif (time[1] in hour_vari) and (len(time)==4):
            try:
                time=int(time[0])*60 + int(time[2])
                return time
            except:
                time=='N/A'
                return time
        elif (len(time)>2) and (time[1] in minute_vari) and(any(time for item2 in hour_vari)!=True):
            return time[0]
        else:
            return 'N/A'

# %%
def currency_clean(str_):
    str_=str(str_)
    str_=str_.lower()
    str_=str_.strip()
    if str_[0]=='[':
        str_=str_[1:]
        
    if '–' in str_:
        str_=str_.split('–')[1]
        str_='$'+str_
    
    if '\xa0' in str_:
        str_=str_.replace('\xa0',' ')
        
    if len(str_.split('['))>1:
        str_=str_.split('[')[0]
        
    
    if ',' in str_:
        str_=str_.replace(',','')
    
    ## million clean
    
    if (re.search(r'\d\.\d\smillion',str_)!= None):
        str_=str_.replace(' ','')
        str_=str_.replace('.','')
        str_=str_.replace('million','00000')

    if (re.search(r'\d\.\d\d\smillion',str_)!= None):
        str_=str_.replace(' ','')
        str_=str_.replace('.','')
        str_=str_.replace('million','0000')
    
    if (re.search(r'\d\.\d\d\d\smillion',str_)!= None):
        str_=str_.replace(' ','')
        str_=str_.replace('.','')
        str_=str_.replace('million','000')
    
    if (re.search(r'\d\.\d\d\d\d\smillion',str_)!= None):
        str_=str_.replace(' ','')
        str_=str_.replace('.','')
        str_=str_.replace('million','00')

    
    if (re.search(r'\d\smillion',str_)!= None) or(re.search(r'\d\d\smillion',str_)!= None) or(re.search(r'\d\d\d\smillion',str_)!= None) :
        str_=str_.replace(' ','')
        str_=str_.replace('.','')
        str_=str_.replace('million','000000')
    
    ## billion clean
    if (re.search(r'\d\.\d\sbillion',str_)!= None):
        str_=str_.replace(' ','')
        str_=str_.replace('.','')
        str_=str_.replace('billion','00000000')
    
    if (re.search(r'\d\.\d\d\sbillion',str_)!= None):
        str_=str_.replace(' ','')
        str_=str_.replace('.','')
        str_=str_.replace('billion','0000000')
    
    if (re.search(r'\d\.\d\d\d\sbillion',str_)!= None):
        str_=str_.replace(' ','')
        str_=str_.replace('.','')
        str_=str_.replace('billion','000000')
    
    if (re.search(r'\d\.\d\d\d\d\sbillion',str_)!= None):
        str_=str_.replace(' ','')
        str_=str_.replace('.','')
        str_=str_.replace('billion','00000')
    
    if (re.search(r'\d\sbillion',str_)!= None) or(re.search(r'\d\d\sbillion',str_)!= None) or(re.search(r'\d\d\d\sbillion',str_)!= None) :
        str_=str_.replace(' ','')
        str_=str_.replace('.','')
        str_=str_.replace('billion','000000000')
    
    if len(str_.split('('))>1:
        str_=str_.split('(')[0]
    
    if len(str_)<5:
        return 'N/A'

    if re.search('[^0-9\$\.]',str_)!=None:
        return 'N/A'
    try:
        str_=re.findall(r'\$.+',str_)
        if len(str_)>11:
            return 'N/A'
        return str_[0]
    except:
        return str_

# %%
film_table['Release date'].fillna('N/A',inplace=True)
film_table['Release date']=film_table['Release date'].apply(clean_date)
# Out:
# C:\Users\Conor\AppData\Local\Temp/ipykernel_7192/637059072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   film_table['Release date']=film_table['Release date'].apply(clean_date)

# %%
film_table['Running time'].fillna('N/A',inplace=True)
film_table['Running time']=film_table['Running time'].apply(time_clean)
# Out:
# C:\Users\Conor\AppData\Local\Temp/ipykernel_7192/3026048073.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   film_table['Running time']=film_table['Running time'].apply(time_clean)

# %%
film_table['Country'].fillna('N/A',inplace=True)
film_table['Language'].fillna('N/A',inplace=True)
film_table['Budget'].fillna('N/A',inplace=True)
film_table['Box office'].fillna('N/A',inplace=True)
film_table['Budget']=film_table['Budget'].apply(currency_clean)
film_table['Box office']=film_table['Box office'].apply(currency_clean)
# Out:
# C:\Users\Conor\AppData\Local\Temp/ipykernel_7192/3484908968.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   film_table['Budget']=film_table['Budget'].apply(currency_clean)
# ₹200 crore (us$26 million)
# $4.4 million[1][2]
# $15 million[2][3][4]
# $22 million[2][3]
# $160 million[2][3][4]
# ₹90 million
# ₹210 million
# $13 million[3][4]
# $54.7 million[5][6]
# $84.5 million[4][5][6][7]
# $8 million
# $15 million[3][4]
# $65 million[2][3]
# $55 million[1][2]
# $35 million
# £3 million[1]($4.4 million[2])
# $26 million
# $5.3 million
# $225 million[1][2][3]
# $27 million[3][4]
# $70 million
# $13.5 million
# ₹15 crore (us$2.0 million)
# $15 million[4][5]
# $110 million[4][5]
# £1 million
# $13.5 million[2][3]
# ₹0.95 crore (equivalent to ₹7.0 crore or us$910,000 in 2020)
# ₹150 million
# $61 million
# $100 million[6][7]
# $2.5 million
# $$225 million[4][5]
# $$225 million[4][5]
# ₹80 lakh (equivalent to ₹13 crore or us$1.7 million in 2020)
# $3 million[3][4]
# us$12 million
# $16.4 million
# $140 million[1][2][3]
# $25 million
# est.₹8.1 million
# $90 million
# $175 million
# $70 million
# $200 million[2][3]
# us$7 million
# $65 million
# $10 million
# $74 million[2][3]
# $35 million
# $15 million
# ₹10 crore (us$1.3 million)
# $51 million
# $5 million[1][2]
# $15 million[1][2]
# $1.1 million
# $49 million
# $160 million[1][2][3]
# $160 million[1][2][3]
# $70 million
# $120 million[2][3][4][nb 1]
# $22 million[2][3]
# $90 million
# $23 million
# $40 million
# $185 million[1][2]
# $28 million[2][3]
# $3.2 million
# more than $6 million
# $15 million
# $30 million[1][better source needed]
# $400 million
# ₹360 million (us$4.7 million)
# $250 million
# $22 million
# $66 million[3][4]
# $40 million[3][2]
# ₹23 crore (us$3.0 million)
# ₹16 crore (us$2.1 million)
# $70 million[7][8]
# $90 million[3][4]
# $120 million (net)[3]']
# $17 million[1][better source needed]
# $1.8 million
# $28 million
# r$ 6 million
# $12 million
# $250 million[3][4]
# $30.5 million
# $125 million[2][3]
# $28 million
# $165 million[3][4]
# $127 million
# $115 million[3][4]
# $102 million
# $200 million[5][6][7]
# $120 million[2]
# us$7.5 million
# $255 million[4][5][6]
# $255 million[4][5][6]
# $85 million[2][3]
# $15 million
# $73 million
# $4.6 million[1][2]
# $63 million
# $7 million
# ₹210 million (us$2.8 million)
# $350 million[4][5][6]
# ₹36 crore (us$4.7 million)
# $2.5 million [1][time needed]
# $$3.8 million[2][3]
# rm 1.5 million
# $38 million
# $$32 million
# $$32 million
# $12.6 million
# $75 million
# $40 million
# $85 million[4][5]
# $2.2 million
# €35 million
# $195 million[2][3]
# $205 million (net)[6][7][8]']
# $1.7 million
# $12 million[3][2]
# ₹4 crore (equivalent to ₹12 crore or us$1.5 million in 2020)
# ₹310 million
# ₹535 million (us$7.0 million)
# $3.2 million
# 28 million
# $7 million
# $100 million
# $130 million
# $150 million
# ₹10 crore (equivalent to ₹13 crore or us$1.7 million in 2020)
# ₹115 crore (₹1.15 billion)
# $40 million
# $19 million[1][2]
# $3 million
# $25 million[2][3][4]
# $15 million(equivalent to $40.3 million in 2020)
# $20 million
# usd$12.5 million[5](120 million
# $129 million[4][5]
# $45 million[6][5]
# $4 million[citation need
# $25 million[1][2]
# $14 million
# $13 million[1][2]
# ₹350 million (us$4.6 million)
# $45 million[1][2]
# $300 million
# $90 million[3][4]
# $178 million[2][3]
# $7.4 million[2][3]
# $42.7 million[2][3]
# $57 million[1][2]
# $21 million
# ₹5 crore
# $61 million[8][9]
# $15 million
# $34 million[1][2]
# rs 110 million
# ₨40 million
# $58 million[2][3]
# $300 million[3][4][5]
# $400 million[2][3]
# $45 million
# $26 million
# 3.7 million ℛℳ (equivalent to €14.7 million in 2009)
# $65 million
# $5 million
# ₹ 80 million
# $7.5 million
# $65 million[1][2]
# $14 million[2][3]
# ₹1.5 crore (equivalent to ₹2.9 crore or us$380,000 in 2020)
# $10 million[1][2][3]
# $35 million[1][2]
# $530,000[1][2][3]
# $1.1 million
# $16 million[3][4]
# ₹260 million
# ₹258 million (us$3.4 million)
# $40 million
# ₹65 crore[2] (note: not including promotion and advertising costs)[better source needed]
# $160 million[2][3]
# $150 crore[4][5]
# $5.7 million
# $15 million (theatrical rentals)
# ₹714 million
# $2 million
# ₹28 crore (us$3.7 million)
# ₹495.9 million
# $378 million
# $215.4 million
# $1.024 billion
# $12.7 million
# $3.3 million
# ₹500 million
# $40 million
# $119.7 million
# est. ₹221 million (see below)
# $81.6 million
# $14.8 million (domestic)
# $26 million
# $7.1 million
# $44 million[2][3]
# $24.5 million
# ₹100 crore (us$13 million)
# $41.2 million
# $203.2 million
# $407.7 million
# ₹730 million (equivalent to ₹1.1 billion or us$14 million in 2020)
# est. ₹ 430 million[2] ($9 million)[4]
# $8.6 million
# ₹1.2 billion (us$16 million)
# $104.6 million
# $2.8 million (united states)
# $6 million[4] or $2.8 million (north america)[3]
# $24.6 million
# $473.1 million
# $134.7 million
# $190 million
# $5 million
# $104 million
# $1.236 billion
# rm12.1 million
# $9.64 million (united states)
# $335.1 million
# $361.8 million
# $47.8 million
# ₹572 million (us$7.5 million)
# $153 million
# ₹33.46 crore (equivalent to ₹122 crore or us$16 million in 2020)
# $25.67 million
# $37.9 million (north america)[2][3]
# $79 million
# ₹10.5 crore (us$1.4 million)(until tuesday)
# $45 million
# $1.2 million
# ₹177.95 million
# $83.3 million
# $270.2 million
# $14.5 million
# $157.9 million
# $95.5 million
# ₹7.88 crore (equivalent to ₹23 crore or us$3.0 million in 2020)
# $30.6 million[4][5]
# ₹10.2 crore (us$1.3 million)
# ₨21.60 crore (us$1.3 million)[1][2]
# $911.1 million
# $354.8 million
# $123.3 million
# $91.5 million
# $4.3 million[4][3]
# $100 million (estimated)
# $363.3 million
# $63 million
# $57.8 million (us and canada)$40.3 million (worldwide theatrical rental)
# $131.2 million
# $21,333,333 (united states)
# $86 million
# $16.8 million
# est. ₹ 65.97 crore (see below)
# $15 million (us)[2][3]
# $103.1 million
# $353.1 million
# ₹6.24 crore
# $12.4 million
# $2 crore[1][2]
# $99.7 crore[4][5]
# $173 million
# $42.1 million
# $785 million
# $245.7 million
# $40 crore[1][3]
# est. ₹97.5 crore
# $21.1 million (a$31.5 million)
# $677.7 million
# $179.3 million
# 380.34 million
# $225 million(equivalent to $1.07 billion in 2021)
# $752.6 million
# 2,638,507 admissions (france)$1.2 million (us/canada rentals)
# $622.7 million
# $644.8 million
# $817.4 million
# ₹60 million (equivalent to ₹110 million or us$1.4 million in 2020)
# $119.2 million
# $322.2 million
# $16.2 million[3][4]
# $5.9 million (us)
# $78.9 million
# $807.8 million
# $30 million
# $1.153 billion
# ₹15 crore (us$2.0 million)
# ₹16.21 crore (equivalent to ₹82 crore or us$11 million in 2020)
# $543.9 million
# $207 million
# $1.034 billion
# $21.7 million[4][5]
# ₹63.29 crore (us$8.3 million)
# $365.6 million
# $19.8 million
# $206.7 million
# $134.1 million
# ₹21.13 crore
# $7.5 million (rentals)
# $751.1 million[5][6]
# $26.1 million
# $70 million[6][7]
# $272.7 million
# $90.3 million
# $290.9 million
# $213.2 million
# $171,082 (north america)
# $429.6 million
# $2.3 million[6][7]
# $20.8 million
# $474.8 million
# ₹100 crore (us$13 million)(two films)
# est. ₹30.9 crore (worldwide share)[2][better source needed]
# $41.1 million
# ₹28.52 crore (us$3.7 million)
# $20.3 million
# $21.7 million
# $10 million
# $38 million[2][3]
# $156.1 million
# ₹540 million
# $275.7 million
# $61.3 million
# $51.4 million
# ₹291 million (us$3.8 million)
# $38.6 million
# $278.5 million
# ₹400 million (us$5.2 million)
# $4.2 million (us/japan rentals)
# 8 million ℛℳ (equivalent to €30.2 million in 2009)
# ₹110 million (us$1.4 million)
# ₹823.3 million
# $1 million
# $159.2 million
# ₹10 crore (us$1.3 million)
# $88.3 million[4][5]
# $57.1 million
# $30.2 million
# $14.4 million
# est. ₹ 13 crores [2] to  ₹20 crore (us$2.6 million)[3][better source needed]
# $5.3 million
# $352.9 million
# $238.2 million
# $300.9 million
# $182 million
# $304.3 million
# $146 million
# $106.4 million
# $33.4 million
# $51.9 million[2][3]
# ₹490 million (us$6.4 million)
# est. ₹79.43 crore (us$10 million)
# ₹36 crore (us$4.7 million)
# $14 million
# r$ 2.9 million[3][4]
# $110.8 million
# $549 million
# $549 million
# $41.2 million
# $657.9 million
# $363.2 million
# $520.9 million
# $1.264 billion
# $70 million
# 3.9 million
# $3.4 million
# $618.6 million
# $184 million
# ₹334 million (us$4.4 million)
# ₹28 crore (us$3.7 million)
# $56 million[4][3]
# rm 1.5 million
# $48.9 million
# $231.3 million
# $45 million (rentals)
# $296.3 million[2][3]
# $161.8 million
# $7.7 million
# $115.9 million
# $1.25 million (us/canada rentals)
# ₹1 crore (equivalent to ₹2.9 crore or us$380,000 in 2020)
# ₹2.25 billion (us$30 million)
# $8 million
# $5.8 million
# $75.7 million[7][8]
# $603.9 million
# $5,000,000 [2][better source needed]
# ₹32 crore (equivalent to ₹41 crore or us$5.4 million in 2020)
# ₹423 crore (₹4.23 billion)
# $97.1 million
# $29.9 million
# $67.18 million(equivalent to $181 million in 2020)
# $4.5 million
# $3.3 million[3][4]
# $45.6 million[5][6](416 million kr)
# $48.8 million
# ₹250 million (us$3.3 million)
# $960.9 million
# $449.3 million
# $68.3 million
# ₹13 crore
# $34.3 million
# $441.8 million
# ₹9.65 billion[11] (see bel
# $20.5 million
# $348.3 million
# rs 300 million (us$3.0 million) (worldwide)[1][2]
# est. ₨152 million[1][2][3]
# ₹10 crore (us$1.3 million)
# $2.048 billion
# $102.4 million
# $90.4 million
# $350 million[2][1][3][4]
# 4.9 million ℛℳ (equivalent to €19.4 million in 2009)
# $250.8 million
# $39.6 million[2]
# $6.7 million
# ₹ 107.5 million
# $33.7 million
# ₹5 crore (equivalent to ₹9.5 crore or us$1.3 million in 2020)
# $79.1 million[3][2]
# $511.8 million
# ₹5.25 crore (7 days collection)(see below)
# $8 million[1][3]
# $59.5 million
# ₹1,150 million (us$15 million)
# $4.0 million[2][3]
# $877.2 million
# $140.7 million
# ₹20 crore (us$2.6 million)
# $58.5 million
# $164 million
# ₹500 million
# $14 million
# $589.4 million
# ৳9.1 crore[1] to ₹9.1 crores [2]
# $244.4 million
# $239.3 million
# 02 million rs[1][2]
# ₹505 million (us$6.6 million)
# $122 million
# $250.2 million
# $1.005 billion
# $84.9 million[1] (equivalent to $238 million 20
# $293.5 million
# $11 million
# $131.5 million
# $225.9 million
# $517.4 million[n 2][n 3]
# $273.6 million
# $183.9 million
# $52.9 million
# $303.1 million
# ₹13.82 crore (equivalent to ₹49 crore or us$6.4 million in 2020)
# ₹180 crore (us$24 million)
# $4 million (rentals)
# $11 million
# $98.1 million
# $9.2 million
# $940.3 million
# $27.4 crore[3][4]
# $24.1 million
# $31 million[2][1]
# $154.6 million
# $176.6 million
# ₹15 crores
# $₹23 crore[2][3][4]
# $75.3 million
# $28.8 million
# $462 million
# $8 million
# $73 million
# $7.1 million
# $43.8 million (theatrical rentals)
# $36 million
# $743.6 million
# $46.5 million (uk & us)
# est. ₹15 crore (us$2.0 million) (50 days)[2][3]
# $13 million
# ₹1.1 crore (equivalent to ₹5.1 crore or us$670,000 in 2020)
# $15,840,000[4][better source needed]
# $1.067 billion
# $631.6 million
# $266.92 million
# $62.9 million
# $24.4 million
# $25.5 million
# $28.6 million
# est. ₹13.10 crore (us$1.7 million)
# ₹83 crore
# $8.6 million (north america)[2][3]
# $441.3 million
# $100 million
# ₹35.21 crore (equivalent to ₹135 crore or us$18 million in 2020)verdict: super hit
# $5.4 million
# $5.5 million (north american rentals)
# ₹917 million
# $257.6 million
# ₹20 crore (us$2.6 million)[2][4][3]
# ₹2.32 crore (equivalent to ₹7.0 crore or us$920,000 in 2020)
# $ $915,840[2][3]
# $244.8 million
# ₹11 million
# ₹548 million (us$7.2 million)
# $164.1 million
# $1.6 million (re-releases)
# $32 million
# $61.6 million
# ₹700 million (us$9.2 million)
# $124.6 million
# $13 crore
# $10.6 million
# $143 million
# ₹10 crore (us$1.3 million)  (50 days collection)
# ₹15.19 crore (us$2.0 million)
# ₹67.84 crore (equivalent to ₹119 crore or us$16 million in 2020)
# $$83.3 million (united states and canada)[4][5]
# ₹15 crore (us$2.0 million)
# ₹15 crore (equivalent to ₹47 crore or us$6.1 million in 2020)
# $3.2 million
# $712 million
# $13.1 million
# $351,447 (north america)
# $52.7 million[3][4]
# $183 million[3][better source needed]
# $8.2 million
# $116.4 million
# ₹14.1 crore (us$1.9 million)
# ₹62.95 crore (us$8.3 million)
# $$11.6 million[3][4]
# $255 million
# $678.2 million
# $3.1 million
# est. ₹93.08 crore (us$12 million)
# ₹970 million (us$13 million)(worldwide)
# ₹645 million (us$8.5 million)
# $66.3 million
# $2.4 million (norway)
# $159.56 crore(45 days)
# ₹710 million (us$9.3 million)
# $19.3 million
# $13.6 million
# ₹74 million
# ₹227 million
# $43 million
# $130.3 million
# $198.7 million
# ₹21.49 crore (equivalent to ₹82 crore or us$11 million in 2020)
# ₹87.8 million (us$1.2 million)
# 72.4 million
# $142 million
# $463.4 million
# $25.9 million
# $146 million
# $17.9 million
# ₹380 million (us$5.0 million)
# $11.6 million (us)
# $20 million
# $4 million[4][5]
# $45.3 million
# $6.1 million
# ₹100.2 million (us$1.3 million)
# ₹07.5 million
# $2.2 million (est. us/ canada rentals)
# $325.3 million
# $215.9 million[3][4]
# est. ₹547.9 million
# $9 million
# ₹600 million
# ₹8 crore (equivalent to ₹21 crore or us$2.7 million in 2020)
# $443,524 (usa)[2][better source needed]
# $299.3 million
# $355.2 million
# $23.9 million[5][2]
# $23.9 million[5][2]
# ₹7 crore
# $222.7 million
# ₹30 crore (us$3.9 million)
# $169.6 million
# $83.1 million
# $11.7 million
# $45.4 million
# $ 3.18 crore
# ₹62 crore (us$8.1 million)
# ₹143 million (us$1.9 million)
# $117 million
# $60 million
# $96.8 million
# $1.128 billion
# est. ₹150.63 million
# $172.4 million
# ₹3.20 crore (equivalent to ₹21 crore or us$2.7 million in 2020)
# $315.2 million
# ₹293 million (us$3.8 million)
# $863.8 million
# ₹420 million (equivalent to ₹670 million or us$8.8 million in 2020)
# $465,000
# ₹85.2 crore[4] ($19 million)[3]
# ₹11 crore (equivalent to ₹26 crore or us$3.4 million in 2020)
# $193.9 million
# $140 million
# $326.7 million
# $319.5 million
# $2.798 billion
# ₹90 million (us$1.2 million)
# ₹1.17 billion (us$15 million)(worldwide)[2][3]
# $10.8 million
# ₹16,19,37,500 (equivalent to ₹590 million or us$7.8 million in 2020)
# ₹256 million (us$3.4 million)
# $8 million (us)
# ₹15 crore (us$2.0 million)
# $12 million (usa)
# $34 million[2][3]
# $88.5 million[2][3]
# $37.8 million
# >$390 million
# $585.8 million
# $373 million
# $20.7 million
# ₹100 million
# $84 million
# $16.3 million
# $195.3 million
# $10.4 million
# $12 million
# ₹46.2 crore (us$6.1 million)
# $261.4 million
# ₹18.82 crore (equivalent to ₹72 crore or us$9.5 million in 2020)
# ₹27.95 crore (us$3.7 million)
# ₹65.57 crore (equivalent to ₹284 crore or us$37 million in 2020)
# ₹18.56 crore (equivalent to ₹60 crore or us$7.9 million in 2020)
# $141.5 million
# $141.5 million
# $854 million
# $13.6 million
# $5.1 million[12][8][13]
# ₹9 crore (us$1.2 million) (all time) ₹4.05 crore (us$530,000) (1st weekend)
# $200.5 million
# $3 million
# ₹200 million (us$2.6 million)(domestic net)[3][4]
# $1.051 billion
# est.₹187.5 million (us$2.5 million)
# ₹14.5 crore (equivalent to ₹252 crore or us$33 million in 2020)
# $1.245 billion
# $10.2 million[2][3]
# ₹37.79 crore (us$5.0 million)
# $81.4 million
# est. ₹58 crores
# nt$260 million
# ₹14.7 crore (equivalent to ₹64 crore or us$8.4 million in 2020)
# est. ₹83 crore
# ₹40 crore (us$5.2 million)
# $825 million
# $181 million
# $1.88 billion
# $1.88 billion
# $33.5 million
# ₹239.61 million (equivalent to ₹750 million or us$9.8 million in 2020)
# $114 million
# $20 million
# $105.2 million
# $288.2 million
# $321.7 million
# $95 million
# $46.7 million
# ₹550 million
# $8.4 million
# $1.450 billion
# ₹38.27 crore (us$5.0 million)[1][2]
# ₹429 million (us$5.6 million)
# $90.4 million
# $553.7 million
# ₹194 million
# ₹23 crore (equivalent to ₹100 crore or us$13 million in 2020)
# $122.1 million
# $8.2 million
# ₹1.22 crore (equivalent to ₹24 crore or us$3.1 million in 2020)
# ₹10.88 crore (us$1.4 million)
# $577.4 million
# ₹32.6 million
# est. ₹167 crore
# ₹ 480 million
# $41.6 million
# C:\Users\Conor\AppData\Local\Temp/ipykernel_7192/3484908968.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   film_table['Box office']=film_table['Box office'].apply(currency_clean)

# %%
film_table=film_table[(film_table['Budget']!='N/A')&(film_table['Box office']!='N/A')]

# %%
decom=decom[decom.index.isin(film_table.index)]

# %%
## function that forces string to have common delim for split.

def common_delim(str_):
    if str_.find(',')>-1:
        return str_
    elif len(re.split(r'[a-z][A-Z]',str_))>1:
        if len(re.split(r'[A-Z][a-z][A-Z]',str_))>1:
            return str_
        split_list=[]
        i_s=0
        for i_e in re.finditer(r'[a-z][A-Z]',str_):
            split_list.append(str_[i_s:i_e.start()+1])
            i_s=len(str_[:i_e.start()+1])
            i_e=i_e.start()+1
        split_list.append(str_[i_e:len(str_)])
        return split_list
    elif len(re.findall(r'[A-Z][a-z]+\s[A-Z][a-z]+\s|[A-Z][a-z]+\s[A-Z][a-z]+',str_))>1:
        multiple_names=re.findall(r'[A-Z][a-z]+\s[A-Z][a-z]+\s|[A-Z][a-z]+\s[A-Z][a-z]+',str_)
        return multiple_names
    else:
        return str_

# %%
## function that creates film_xx connection table and unique look up table stored both in dictionary.

def lookup_idtable(col,c):
    output={}
    decom[col]=decom[col].apply(lambda x:str(x))
    decom[col]=decom[col].apply(common_delim)
    decom[col]=decom[col].apply(lambda x:str(x))
    table=decom[col].str.split(',',expand=True)

    ## cleans strings from the new df
    ## creates a df of unique values 

    for i in list(range(0,len(table.columns))):    
        table[i]=table[i].apply(lambda x:re.sub('\W+',' ', str(x) ))
        table[i]=table[i].apply(lambda x:x.strip())
        table[i].fillna('N/A',inplace=True)

    b_=[]
    for i in list(range(0,len(table.columns))):
        b_.extend(list(table[(table[i]!='None')|(table[i]!='N/A')].iloc[:][i]))
    
    b_lis=pd.Series(b_)
    b_lookup=pd.DataFrame(b_lis.unique())
    b_lookup.reset_index(inplace=True)
    b_lookup.columns=['id',c]
    
    output['lookup']=b_lookup
    ##intermediate df in prep for 
    inter_df=table.join(df)
    cols=list(range(0,len(table.columns)))
    cols.append('name')
    inter_df=inter_df[cols]

    ## Creates a df of every combination of director and film for the CONNECTOR table

    film_b=pd.DataFrame()
    count=0
    for index, row in inter_df.iterrows():
        df_i=pd.DataFrame(row[(row!='None')]).iloc[:-1]
        df_i['film']=row[(row!='None')].iloc[-1]
        df_i.columns=[[c,'film']]
        film_b=pd.concat([film_b,df_i])
        count=count+1
        if (count % 1000)==0:
            print(count)
    film_b.reset_index(inplace=True)
    film_b.drop(['index'],axis=1,inplace=True)
    film_b.columns=[c,'film']

    film_b_id= pd.merge(left=film_b, right=film_table_conn,on='film',how='left' )
    film_b_id=pd.merge(left=film_b_id, right=b_lookup,on=c,how='left' )
    film_b_id=film_b_id[['id_x','id_y']]
    film_b_id.reset_index(inplace=True)
    film_b_id.columns=['unique_id','film_id',c+'_id']
    output['id']=film_b_id
    return output

# %%
film_table_conn= film_table[['name','id']]
film_table_conn.columns=['film','id']

# %%
dict_names=['Directors','Writers','Producers','Actors','Editors','composers','Productioncompanies','distributors']
list_a=['Directed by','Written by','Produced by','Starring','Edited by','Music by','Productioncompanies','Distributed by']
list_c=['Director','Writer','Producer','Actor','Editor','composer','Productioncompany','distributor']

# %%
output={}
zipped_list=list(zip(dict_names,list_a,list_c))
for table,col,id_name in zipped_list:
    inter_dict=lookup_idtable(col,id_name)
    output[table]=inter_dict
    print(table)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# C:\Users\Conor\anaconda3\lib\site-packages\pandas\core\generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# Directors
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# Writers
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# Producers
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# Actors
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# Editors
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# composers
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# Productioncompanies
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# distributors

# %%
conn = sqlite3.connect('clean_film_data.sqlite')
cur = conn.cursor()
zipped_list_b=list(zip(list_c,dict_names))
for name_,names in zipped_list_b:
    cur.executescript('''
    DROP TABLE IF EXISTS '''+names+''';
    CREATE TABLE'''+' '+ names+''' (
    id     INTEGER NOT NULL PRIMARY KEY UNIQUE,
    '''+name_+'''   TEXT UNIQUE
    );
    ''')
#insert df's into SQL DB
    for index, row in output[names]['lookup'].iterrows():
        cur.execute("INSERT INTO"+" "+names+"  (id,"+name_+") VALUES (?,?)",(row))
    conn.commit()
cur.close()

# %%
sqlite3.register_adapter(np.int64, int)
conn = sqlite3.connect('clean_film_data.sqlite')
cur = conn.cursor()
zipped_list_b=list(zip(list_c,dict_names))
for name_,names in zipped_list_b:
    cur.executescript('''
    DROP TABLE IF EXISTS '''+names+'''_film_id;
    CREATE TABLE'''+' '+ names+'''_film_id (
    unique_id     INTEGER NOT NULL PRIMARY KEY UNIQUE,
    film_id       INTEGER NOT NULL,
    '''+name_+'''_id  INTEGER NOT NULL
    );
    ''')
#insert df's into SQL DB
    for index, row in output[names]['id'].iterrows():
        
        cur.execute("INSERT INTO"+" "+names+"_film_id (unique_id,film_id,"+name_+"_id) VALUES (?,?,?)",(row))
    conn.commit()
cur.close()

# %%
for col in list(film_table.columns[2:]):
    film_table[col]=film_table[col].apply(lambda x:str(x))

# %%
conn = sqlite3.connect('clean_film_data.sqlite')
cur = conn.cursor()

cur.executescript('''
DROP TABLE IF EXISTS film_table;
CREATE TABLE film_table (
film   TEXT NOT NULL,
id     INTEGER NOT NULL PRIMARY KEY UNIQUE,
release_date TEXT,
running_time_mins TEXT,
country TEXT,
language TEXT,
budget TEXT,
box_office TEXT


    );
    ''')
#insert df's into SQL DB
for index, row in film_table.iterrows():
    cur.execute("INSERT INTO film_table (film, id, release_date, running_time_mins, country, language,budget, box_office) VALUES (?,?,?,?,?,?,?,?)",(row))
conn.commit()
cur.close()
